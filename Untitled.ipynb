# %%
from __future__ import print_function
from pylab import *
from numpy import *
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

# %%
def f(m, b):
    plt.figure(2)
    x = np.linspace(-10, 10, num=1000)
    plt.plot(x, m * x + b)
    plt.ylim(-5, 5)
    plt.show()

interactive_plot = interactive(f, m=(-2.0, 2.0), b=(-3, 3, 0.5))
output = interactive_plot.children[-1]
output.layout.height = '350px'
interactive_plot
# Out:
# interactive(children=(FloatSlider(value=0.0, description='m', max=2.0, min=-2.0), FloatSlider(value=0.0, descr…

# %%
x=linspace(-pi,pi)
y=sin(x)
figure(figsize=(12,3)) #This controls the size of the figure
subplot(2,3,1) #This is the first plot in a 2x3 grid of plots
plot(x,y)
subplot(2,3,2)#this is the second plot
plot(x,y,linestyle='--') # Demo using 'linestyle' keyword arguement
subplot(2,3,3)
plot(x,y,'.')
subplot(2,3,4)
plot(x,y,'-.')
subplot(2,3,5)
plot(x,y,'.-')
subplot(2,3,6)
plot(x,y,ls=':') # Demo using 'ls' keyword arguement.
show()

# %%
fig = px.choropleth(c_lat_grp, locations="Country", locationmode='country names',
                color="Cases", hover_name="Country", 
                color_continuous_scale="Emrld", title='COVID-19')

fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ce6d78e6a2e8> in <module>
# ----> 1 fig = px.choropleth(c_lat_grp, locations="Country", locationmode='country names',
#       2                 color="Cases", hover_name="Country",
#       3                 color_continuous_scale="Emrld", title='COVID-19')
#       4
#       5 fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
#
# NameError: name 'px' is not defined
